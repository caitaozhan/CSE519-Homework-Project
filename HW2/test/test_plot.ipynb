# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
house_df = pd.read_csv('../data/properties_2016_backup.csv')
# Out:
# D:\Program Files\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
house_df.shape
# Out:
# (2985217, 58)

# %%
house_df.columns
# Out:
# Index(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
# ...

# %%
X = 'finishedsquarefeet15'
Y = 'taxamount'

df = house_df.loc[:,[X,Y]]
df.dropna(how='any', inplace=True)
df = df[df.finishedsquarefeet15 < 110000]
df = df[df.taxamount < 400000]
df = df.groupby(X).mean()
df.plot()

plt.show()

# %%
df
# Out:
#                          taxamount
# finishedsquarefeet15
# 112.0                 3.359120e+03
# 148.0                 4.622710e+03
# 173.0                 1.623270e+03
# 180.0                 1.498360e+03
# 213.0                 3.922870e+03
# 240.0                 4.042597e+03
# 248.0                 1.537200e+02
# 252.0                 4.203570e+03
# 268.0                 3.447860e+03
# 280.0                 5.084680e+03
# 290.0                 2.278610e+03
# 294.0                 1.528800e+03
# 298.0                 1.907650e+03
# 300.0                 1.746835e+03
# 302.0                 1.443460e+03
# 303.0                 1.717825e+03
# 308.0                 2.864755e+03
# 312.0                 5.737200e+02
# 324.0                 1.596730e+03
# 331.0                 1.239200e+02
# 339.0                 7.705150e+03
# 340.0                 1.333900e+03
# 360.0                 9.701050e+02
# 362.0                 8.239430e+03
# 364.0                 7.618140e+03
# ...

# %%
X = 'yearbuilt'
Y = 'parcelid'

df = house_df.loc[:,[X,Y]]
df.dropna(how='any', inplace=True)
df = df[df.yearbuilt>1900]
df = df.groupby(X).count()
df.plot(kind='bar')

plt.show()

# %%
x_ticks=np.arange(df.index, 5)
x_ticks
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-5bc2dc3925f0> in <module>()
# ----> 1 x_ticks=np.arange(df.index, 5)
#       2 x_ticks
#
# TypeError: must be real number, not Float64Index

# %%
df.plot.bar()
plt.xticks(x_ticks)
plt.show()

# %%
df.columns
# Out:
# Index(['parcelid'], dtype='object')

# %%
X = 'yearbuilt'
Y = 'buildingqualitytypeid'

df = house_df.loc[:,[X, Y]]

df.dropna(how='any', inplace=True)
df = df[df.yearbuilt>1900]
df = df.groupby(X).mean()

# %%
df
# Out:
#            parcelid
# yearbuilt
# 1901.0         1486
# 1902.0         1062
# 1903.0         1801
# 1904.0         1565
# 1905.0         4495
# 1906.0         3278
# 1907.0         3666
# 1908.0         4494
# 1909.0         3948
# 1910.0         7843
# 1911.0         5569
# 1912.0         7929
# 1913.0         5733
# 1914.0         4651
# 1915.0         4045
# 1916.0         3042
# 1917.0         2256
# 1918.0         2576
# 1919.0         3927
# 1920.0        10954
# 1921.0        14250
# 1922.0        23726
# 1923.0        32364
# 1924.0        30441
# 1925.0        25322
# 1926.0        22955
# 1927.0        18003
# 1928.0        18571
# 1929.0        14815
# 1930.0        12819
# ...             ...
# 1986.0        38548
# 1987.0        44851
# 1988.0        33742
# 1989.0        52520
# 1990.0        41200
# 1991.0        20166
# 1992.0        18013
# 1993.0        15209
# 1994.0        18761
# 1995.0        16527
# 1996.0        16937
# 1997.0        18032
# ...

# %%
df.plot()

# %%
plt.show()

# %%
df.describe()
# Out:
# count    2.925289e+06
# mean     1.964262e+03
# std      2.344132e+01
# min      1.801000e+03
# 25%      1.950000e+03
# 50%      1.963000e+03
# 75%      1.981000e+03
# max      2.015000e+03
# Name: yearbuilt, dtype: float64

# %%
df.shape
# Out:
# (2925289,)

# %%
X = 'latitude'
Y = 'longitude'

df = house_df.loc[:,[X, Y]]
df.dropna(how='any', inplace=True)
df.plot(x=X, y=Y, kind='scatter')

# %%
plt.show()

# %%
df.describe()
# Out:
#            latitude     longitude
# count  2.973780e+06  2.973780e+06
# mean   3.400147e+07 -1.182019e+08
# std    2.433812e+05  3.453171e+05
# min    3.332439e+07 -1.194758e+08
# 25%    3.382768e+07 -1.183930e+08
# 50%    3.400825e+07 -1.181725e+08
# 75%    3.416186e+07 -1.179495e+08
# max    3.481965e+07 -1.175543e+08

# %%
pd.set_option('display.max_rows', None)

X = 'yearbuilt'
Y = 'buildingqualitytypeid'

df = house_df.loc[:,[X, Y]]
df.head()

df.dropna(how='any', inplace=True)
df = df[df.yearbuilt>1900]
df = df.groupby(X).mean()
df.plot()
plt.show()

# %%
house_df.isnull().sum()
# Out:
# parcelid                              0
# airconditioningtypeid           2173698
# architecturalstyletypeid        2979156
# basementsqft                    2983589
# bathroomcnt                       11462
# bedroomcnt                        11450
# buildingclasstypeid             2972588
# buildingqualitytypeid           1046729
# calculatedbathnbr                128912
# decktypeid                      2968121
# finishedfloor1squarefeet        2782500
# calculatedfinishedsquarefeet      55565
# finishedsquarefeet12             276033
# finishedsquarefeet13            2977545
# finishedsquarefeet15            2794419
# finishedsquarefeet50            2782500
# finishedsquarefeet6             2963216
# fips                              11437
# fireplacecnt                    2672580
# fullbathcnt                      128912
# garagecarcnt                    2101950
# garagetotalsqft                 2101950
# hashottuborspa                  2916203
# ...

# %%
X = 'bedroomcnt'
Y = 'bathroomcnt'

df = house_df.loc[:,[X, Y]]
df.head()

df.dropna(how='any', inplace=True)

# %%
df.plot(x='bedroomcnt', y='bathroomcnt', kind='scatter')

# %%
plt.show()

# %%
df.describe()
# Out:
#          bedroomcnt   bathroomcnt
# count  2.973755e+06  2.973755e+06
# mean   3.088937e+00  2.209143e+00
# std    1.275803e+00  1.077754e+00
# min    0.000000e+00  0.000000e+00
# 25%    2.000000e+00  2.000000e+00
# 50%    3.000000e+00  2.000000e+00
# 75%    4.000000e+00  3.000000e+00
# max    2.000000e+01  2.000000e+01
