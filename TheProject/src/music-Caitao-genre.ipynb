# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import math


from bs4 import BeautifulSoup
import requests
import re
from fuzzywuzzy import fuzz
# Out:
# D:\Program Files\anaconda\lib\site-packages\fuzzywuzzy\fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # 1 Scrape Genre
#
# ## 1.1 Main function

# %%
# test case
artist = 'Booker T. and The M.G.\'s'
title  = 'Groovin\''
url    = 'https://en.wikipedia.org/wiki/Groovin%27'

# %%
def scrape_genre(url, title, artist):
    re_infobox = 'infobox.*'
    
    html = requests.get(url)                             # url  -> html
    soup = BeautifulSoup(html.content, 'html.parser')    # html -> soup object
    infobox_list = soup.find_all('table', class_=re.compile(re_infobox))  # >=2 songs (with same title, different artist) share a same url
    for infobox in infobox_list:
        des_artist = ''
        try:
            description = infobox.find('th', class_='description').get_text()
            des_artist = get_artist(description)
        except Exception as e:                           # no description
            # print(e)
            continue
            
        fuzz_ratio = fuzz.ratio(des_artist, artist)
        if fuzz_ratio < 70:                              # set 70 as threshold
            #print('Artist no match! ',title, des_artist, ' - ', artist, ': ', fuzz_ratio)
            des_artist = des_artist.lower()              # the Beatles and George Martin  -  The Beatles
            artist = artist.lower()                      # they actually should be the same artist
            if des_artist.find(artist) != -1:
                pass #print(artist, ' is substring of ', des_artist)
            elif artist.find(des_artist) != -1:
                pass #print(des_artist, ' is substring of ', artist)
            else:
                continue
        
        category = infobox.find('td', class_='category hlist')  # category may be NoneType (null)
        
        genre = ''
        try:
            genre = category.get_text()
            genre = clean_genre(genre)
        except Exception as e:
            pass #print(e)
            
        return genre
    return ''

# %%
scrape_genre(url, title, artist)

# %%
artist = 'Bob Moore'
des_artist = 'Bob Moore & His Orchestra'
des_artist.find(artist)
# Out:
# 0

# %% [markdown]
# ## 1.2 Clean Genre

# %% [markdown]
# 1. before cleaning:  Rock, country, soul,[1] pop[2]
# 2. after cleaning :   Rock, country, soul, pop

# %%
def clean_genre_2(genre):
    ''' Clean the genre.
    
    Args:
        genre (str): need to be cleaned. eg. 'R&B, blue-eyed soul[1]'
    Return:
        (str): 'R&B, blue-eyed soul'
    '''
    re_genre = '(.*)(\[.*\])(.*)'   # Rock, country, soul,[1] pop[2]
    match = re.search(re_genre, genre)
    if match:
        return match.group(1)+ match.group(3)
    else:
        return genre

# %%
def clean_genre(genre):
    genre = genre.strip('\n')
    genre = genre.replace('\n', ', ')  # get rid of newlines
    while genre.find('[') != -1:
        genre = clean_genre_2(genre)
    return genre.lower()               # lowercase

# %%
genre = 'Rock, country, soul,[1] pop[2]'
print('before cleaning: ', genre)
print('after cleaning:  ', clean_genre(genre))
# Out:
# before cleaning:  Rock, country, soul,[1] pop[2]
# after cleaning:   Rock, country, soul, pop

# %% [markdown]
# ## 1.3 Extract Artist

# %%
def get_artist(description):
    ''' Get the artist from infobox's description
    
    Args:
        description (str): eg. 'Single by The Young Rascals'
    Return:
        (str):             eg. 'The Young Rascals'
    '''
    re_artist  = '(.*) by (.*)'   # eg. Single by The Young Rascals
    
    match = re.search(re_artist, description)
    if match:
        return match.group(2)
    else:
        return 'null'

# %%
description = 'Single by Chubby Checker'
get_artist(description)
# Out:
# 'Chubby Checker'

# %% [markdown]
# ## 1.4 Approximate String Match

# %% [markdown]
# The following two strings should match according to edit distance
#
# 1. Booker T & the M.G.s
# 2. Booker T. and The M.G.'s

# %%
fuzz.ratio('Booker T & the M.G.s',  'Booker T. and The M.G.\'s')
# Out:
# 82

# %% [markdown]
# # 2 Add Genre to Dataframe

# %%
titles_url = pd.read_csv('../music_data/titles_url.csv')
titles_url['GenreRaw'] = pd.Series()                     # create a new column

# %%
# test
song = titles_url.iloc[0,:]
artist = song.Artist
title  = song.Title
url    = song.URL
scrape_genre(url, title, artist)
# Out:
# 'easy listening'

# %%
for i in range(0, len(titles_url)):
    song = titles_url.iloc[i,:]
    if song.isnull()[2] == True:  # url is nan
        continue
    artist = song.Artist
    title  = song.Title
    url    = song.URL
    genre = scrape_genre(url, title, artist)
    song.GenreRaw = genre
    titles_url.iloc[i,:] = song
    print(i, genre)

titles_url.to_csv('../music_data/genres.csv')
# Out:
# 0 easy listening
# 1 country, pop
# 2 pop
# 3 pop
# 4 pop
# 5 country
# 6 rock
# 7 rock
# 8
# 9 rock and roll
# 10 pop, teenage tragedy song
# 11 pop, country
# 12
# 13 pop
# 14 rockabilly
# 15 pop
# 16
# 17 vocal, country
# 18 vocal
# 19 pop
# 20
# 21 pop
# 22 pop
# 23 rock and roll, rhythm and blues
# 24 rock and roll
# 25 pop
# 26 rock and roll, pop
# 27 pop
# 28 pop rock, rock and roll
# 29 pop
# 30 rhythm and blues, rock and roll
# 31 rock and roll, bossa nova
# 32
# 33 rock, country, soul, pop
# 34 country, pop, soul
# 35 rock and roll
# 36 r&b
# 37 rock and roll
# 38
# 40 rock and roll
# 41 rock and roll
# 42 rhythm and blues, rock and roll, soul
# 43 pop
# 44 pop
# 45 pop
# 46 pop
# 47 traditional pop music
# 48 country pop
# 49 country
# 50 rock and roll
# 51
# 52 rock and roll
# 53 pop
# 54 rock and roll
# 55 pop
# 57
# 59 country, tex-mex
# 60 country
# 61
# 62 bubblegum pop
# 63 pop
# 64 pop, rock 'n' roll
# 65 country, rock
# 66 bolero
# 67
# 68 rockabilly
# 69 rock
# 70 rock
# 71
# 72 doo-wop
# 73 traditional pop
# 74 pop
# 79 pop
# 80 rock, surf rock
# 81 rock, surf rock
# 83 r&b, pop
# 84
# 85
# 86 pop, soul
# 87 r&b
# 88
# 89 country
# 90 rhythm and blues, soul
# 91 rhythm and blues, soul
# 92 rhythm and blues
# 93 rhythm and blues, soul
# 94
# 95 r&b, soul
# 96
# 97
# 98
# 99 pop rock
# 100 pop
# 101 folk rock
# 102
# 103
# 104 pop
# 105
# 106 rock and roll
# 107 chicago soul
# 108
# 109
# 110 rock
# 111 pop music
# 112 traditional pop music
# 113 traditional pop music
# 114 pop
# 115
# 116 pop
# 117 novelty
# 118
# 119
# 120
# 121 country
# 122
# 124
# 125
# 126 country
# 127
# 128
# 129
# 130 vocal pop, inspirational, traditional pop, gospel, hymns, contemporary gospel
# 131 easy listening
# 132 easy listening
# 133 countrypolitan
# 134
# 135
# 136 rock and roll, pop
# 137
# 138 pop
# 139
# 140
# 141 easy listening
# 143
# 144 novelty song
# 145 pop
# 147 pop
# 149
# 151 pop
# 152 brill building
# 153 brill building, doo-wop
# 154 jazz, soul, blues, traditional pop
# 155 r&b, jazz
# 156
# 157
# 158 rhythm and blues
# 159 pop
# 162
# 163 ballad
# 164 pop
# 165 rockabilly
# 166
# 167
# 168
# 169
# 170 rockabilly
# 171
# 173 pop
# 175 r&b
# 177 rockabilly
# 178 country
# 179
# 180 doo-wop
# 183 r&b
# 185 country, traditional pop
# 186 country, traditional pop
# 188
# 189 rock and roll
# 190 rock and roll
# 191 pop rock
# 192 rock and roll
# 193 doo-wop
# 194
# 195 r&b
# 196
# 197 easy listening
# 198 pop, soul
# 199 r&b
# 200
# 201 r&b
# 202
# 203 r&b, pop, soul
# 204 r&b, instrumental rock
# 205 pop, easy listening
# 206
# 207
# 208 doo-wop
# 209
# 210 soul
# 211 soul
# 212 soul, pop
# 213 soul
# 214 soul, pop
# 215 soul
# 216 rock and roll
# 217
# 218 folk, world, country
# 219
# 220 doo-wop
# 224 doo-wop, bubblegum pop (sugaryline version)
# 225
# 227 pop
# 228 pop
# 229 country
# 230
# 231 r&b
# 233 r&b, swamp pop, country
# 234 rock, classical
# 235 country
# 236 doo-wop, rock and roll
# 237 rhythm and blues, pop, rock and roll
# 238 rock and roll
# 239 rock and roll
# 240
# 241 rock and roll
# 244
# 245 pop
# 246 soul, rock and roll
# 247 r&b
# 248 pop, country
# 249
# 250 pop, jazz
# 251
# 252
# 253 country pop
# 254
# 255 pop
# 256
# 258 r&b, pop
# 259 rhythm and blues, soul
# 260 soul
# 261 rock & roll, r&b
# 263 pop
# 265 jazz
# 266
# 268 doo-wop
# 269 pop, doo-wop
# 270 skiffle, novelty song
# 271
# 272 country, pop
# 273 pop
# 274 pop
# 276 west coast cool jazz
# 277 country
# 278 easy listening
# 279
# 282 pop
# 283 traditional pop
# 284 traditional pop
# 285 pop
# 286 pop
# 287 jazz
# 288
# 289 pop, rhythm and blues
# 290
# 291 pop
# 292 soul, doo-wop
# 293 rock and roll
# 294 country
# 295 soul
# 296 soul
# 297 soul, r&b, pop
# 299 pop, rockabilly, lubbock sound
# 300 pop rock
# 301 pop rock
# 302 pop rock
# 303 bubblegum pop
# 306 rock and roll
# 307
# 308 pop, r&b
# 309
# 310 jazz, pop
# 311
# 312 rock
# 313 rock
# 314 rock
# 315
# 316
# 318 pop
# 319 rock and roll, r&b
# 320 funk
# 321
# 322
# 324 r&b
# 325 country, pop, nashville sound
# 326
# 327
# 328 rock and roll, doo-wop
# 329
# 332
# 333 soul
# 334
# 335
# 336 rock
# 338
# 339 pop
# 340
# 341 novelty
# 342 pop
# 343
# 344
# 345 rock and roll, pop
# 346 r&b
# 347 rock and roll
# 348
# 350 rhythm & blues
# 351
# 352 r&b, pop, doo-wop
# 353 pop, rock
# 356 pop
# 358 country
# 359
# 362 doo-wop
# 363
# 364
# 365 blues, r&b, rock 'n' roll
# 366
# 367 folk
# 368 folk, pop
# 369 folk
# 370 folk rock, psychedelic folk
# 372
# 373 surf rock, rock and roll
# 374 surf rock, rock and roll
# 375 hot rod rock, car song
# 376 california sound, pop, surf vocal, car song
# 377 rock and roll
# 378 pop rock, art pop, california sound
# 379 psychedelic rock, art pop, acid rock, psychedelic pop, avant-pop, r&b
# 380 folk rock, chamber pop
# 381 rock and roll, doo-wop
# 382 garage rock, rock and roll
# 383 country
# 384 country, girl group
# 385 pop, doo-wop
# 386 pop, doo-wop
# 387 pop
# 388 pop, pop rock
# 389 r&b, soul
# 390 soul
# 391 soul
# 392 r&b, soul
# 393 soul, pop
# 394 pop, dixieland jazz, instrumental
# 395 soul
# 396 chicago soul
# 398 pop
# 399
# 400
# 401 pop, rock, blue-eyed soul
# 402 pop, rock
# 403 pop, r&b
# 404 pop
# 405 doo-wop
# 406 pop, doo-wop
# 407
# 408 surf rock
# 409 surf rock
# 410
# 414
# 415 pop
# 416 surf rock
# 417 vocal surf
# 418 pop, teenage tragedy, car song
# 419 car song
# 420 traditional pop, rock and roll
# 421 soul
# 422 soul
# 423 rhythm and blues, soul
# 424
# 425 soul/pop
# 426 doo-wop
# 427 folk, bluegrass
# 428 folk rock
# 429 pop
# 430 instrumental
# 431 r&b
# 432 r&b
# 433 r&b
# 434 pop
# 436 soul
# 437 rock
# 438 rock
# 439 rock
# 440 rock
# 441 country
# 442 soul blues
# 443 pop
# 444
# 445 pop
# 446
# 447
# 448
# 449
# 450 r&b, pop
# 451 rhythm and blues
# 452 soul/pop
# 453 soul, pop rock
# 454 soul
# 455 soul, psychedelic soul, funk
# 456 r&b, psychedelic soul
# 457 r&b
# 458 country
# 461 r&b
# 462
# 463 country, talking blues, comedy
# 464 rhythm and blues
# 465 novelty song
# 466 folk/pop
# 468 country, easy listening
# 469 rock and roll, pop, pop rock
# 470 rock and roll, pop
# 471
# 472 merseybeat, pop, r&b
# 473 merseybeat, rock and roll, rock, pop
# 474 rock and roll
# 475 pop rock
# 476 pop
# 477 rock and roll
# 478 folk rock
# 479 power pop, jangle pop, folk rock
# 480 rock
# 481 folk rock
# 482 hard rock, power pop, psychedelic rock
# 483 folk rock
# 484 psychedelic rock, orchestral
# 485 pop
# 486 progressive pop, baroque pop, psychedelic pop, psychedelic rock
# 487 rock
# 488 rock and roll, rhythm and blues
# 489 hard rock
# 490 rock, pop
# 491 rock
# 492 traditional pop, jazz
# 493 traditional pop
# 494 traditional pop, country
# 495 folk
# 496
# 497 r&b, pop, doo-wop
# 498 pop, r&b
# 499 pop, r&b, soul
# 500 pop, r&b
# 501 pop, soul, r&b
# 502 soul, pop
# 503 baroque pop, soul
# 504 pop, r&b
# 505 pop
# 506 psychedelic pop, psychedelic soul
# 507 pop, r&b
# 508
# 509 jazz
# 510
# 511 pop rock
# 512 rock
# 513 pop, beat
# 514 pop, beat
# 515 doo-wop
# 516 pop, r&b, soul
# 517 rockabilly
# 518 pop rock
# 519 beat
# 520
# 521 pop
# 522 pop
# 523 merseybeat
